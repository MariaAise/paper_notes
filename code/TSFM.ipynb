# %% [markdown]
# # Re(Visiting) Time Series Foundation Models in Finance
#
# [Link](https://www.arxiv.org/pdf/2511.18578)
#
# I will use the data from [Ken French Data Library](https://mba.tuck.dartmouth.edu/pages/faculty/ken.french/data_library.html) to replicate the method and evaluation
# in this paper.
#
# ### Data
#
# The original paper used
#
# - daily firm-level excess returns spanning 1990–2023 across 94 countries
#
# - The raw equity returns are adjusted for delisting effects, corporate actions, and market conventions to produce a clean, consistent measure of daily stock performance net of the local riskfree rate.
#
# Daily price and return information are obtained from two complementary sources: from the Center for Research in Security Prices (CRSP) database (US firms) and Compustat global daily security files (for non-US).

# %% [markdown]
# ### Data preprocessing
#
# Fama/French 3 Factors [Daily]
